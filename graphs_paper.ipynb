# %% [markdown]
# # Figure DAG and NaCl

# %%
def ldata(archive):
    f=open(archive)
    data=[]
    for line in f:
        e=line.strip()
        col=line.split()
        data.append(col)	
    return data


data=ldata("trajectories_highNaCl.txt")

data_float=[]
data_time=[]
for i in data:
  data_float.append([float(i[0]), float(i[1]), float(i[2]), float(i[3]), float(i[4]), float(i[5]), float(i[6]), float(i[7])])
  data_time.append(float(i[0]))

# %%
times_high = []
sal_high = []
cgmp_high = []
PKG_high = []
Ca_high = []
DAG_HIGH = []
AIB_high = []
glu_basal_high = []


for i in data_float:
    times_high.append(i[0])
    sal_high.append(i[1])
    cgmp_high.append(i[2])
    PKG_high.append(i[3])
    Ca_high.append(i[4])
    DAG_HIGH.append(i[5])
    AIB_high.append(i[6])
    glu_basal_high.append(i[7])

# %%
import matplotlib.pyplot as plt
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()

ax2.plot(times_high[1:], sal_high[1:], color="Grey",alpha=0.5, lw=2)
ax1.plot(times_high[1:], DAG_HIGH[1:],  color="magenta", lw=2)
ax1.axhline(y=0, lw=2, color="k", alpha=1.0, ls="--")

ax1.set_xlabel('time (s)', fontsize=18)
ax1.set_ylabel(r"DAG ($\mu$M)", color="magenta", fontsize=20)
ax2.set_ylabel( "NaCl (mM)", color="Grey",alpha=0.5, fontsize=20, rotation=-90, labelpad=28)

plt.title('High salt cultivated animals',fontweight="bold", fontsize=18, y=1.03)


ax2.tick_params(width=2, axis='both', which='major', labelsize=14)
ax1.tick_params(width=2, axis='both', which='major', labelsize=14)

plt.tight_layout()
#plt.savefig("highsalt_DAG.pdf")
plt.show()

# %%
data=ldata("trajectories_lowNaCl.txt")
#data=ldata("/content/gdrive/MyDrive/Colab Notebooks/paper/random_CI2.txt")
data_float=[]
data_time=[]
for i in data:
  data_float.append([float(i[0]), float(i[1]), float(i[2]), float(i[3]), float(i[4]), float(i[5]), float(i[6]), float(i[7])])
  data_time.append(float(i[0]))

# %%
times_low = []
sal_low = []
cgmp_low = []
PKG_low = []
Ca_low = []
DAG_low = []
AIB_low = []
glu_basal_low = []

for i in data_float:
    times_low.append(i[0])
    sal_low.append(i[1])
    cgmp_low.append(i[2])
    PKG_low.append(i[3])
    Ca_low.append(i[4])
    DAG_low.append(i[5])
    AIB_low.append(i[6])
    glu_basal_low.append(i[7])

# %%
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()

ax2.plot(times_low[1:], sal_low[1:], color="Grey",alpha=0.5, lw=2)
ax1.plot(times_low[1:], DAG_low[1:],  color="magenta", lw=2)
ax1.axhline(y=0, lw=2, color="k", alpha=1.0, ls="--")

ax1.set_xlabel('time (s)', fontsize=18)
ax1.set_ylabel(r"DAG ($\mu$M)", color="magenta", fontsize=20)

ax2.set_ylabel( "NaCl (mM)", color="Grey",alpha=0.5, fontsize=20, rotation=-90, labelpad=28)
plt.title('Low salt cultivated animals',fontweight="bold", fontsize=18, y=1.03)


ax2.tick_params(width=2, axis='both', which='major', labelsize=14)
ax1.tick_params(width=2, axis='both', which='major', labelsize=14)

plt.tight_layout()
#plt.savefig("lowsalt_DAG.pdf")
plt.show()

# %% [markdown]
# # Figure worms' trajectories with different pre-assay cultivation [NaCl]

# %% [markdown]
# # Low salt

# %%
import numpy as np
def ldata(archive):
    f=open(archive)
    data=[]
    for line in f:
        e=line.strip()
        col=line.split()
        data.append(col)	
    return data


#data=ldata("/content/gdrive/MyDrive/Colab Notebooks/paper/ATRACCION_trayectorias.txt")
data=ldata("REPULSION_trayectorias.txt")
#data=ldata("/content/gdrive/MyDrive/Colab Notebooks/paper/random_trayectorias.txt")
data_float=[]
data_time=[]
for i in data:
  data_float.append([float(i[0]), float(i[1]), float(i[2]), float(i[3]), float(i[4]), float(i[5]), float(i[6]), float(i[7])])
  data_time.append(float(i[0]))

# %%
times_end = np.argwhere(np.array(data_time) == max(data_time))

# %%
ang_1 = []
ang_2 = []
ang_3 = []
ang_4 = []
ang_5 = []
ang_6 = []
ang_7 = []
ang_8 = []
ang_9 = []
ang_10 = []
for i in range(int(times_end[0])):
  ang_1.append(data_float[i])
for i in range(int(times_end[0]),int(times_end[1])):
  ang_2.append(data_float[i])
for i in range(int(times_end[1]),int(times_end[2])):
  ang_3.append(data_float[i])
for i in range(int(times_end[2]),int(times_end[3])):
  ang_4.append(data_float[i])
for i in range(int(times_end[3]),int(times_end[4])):
  ang_5.append(data_float[i])
for i in range(int(times_end[4]),int(times_end[5])):
  ang_6.append(data_float[i])
for i in range(int(times_end[5]),int(times_end[6])):
  ang_7.append(data_float[i])
for i in range(int(times_end[6]),int(times_end[7])):
  ang_8.append(data_float[i])
for i in range(int(times_end[7]),int(times_end[8])):
  ang_9.append(data_float[i])
for i in range(int(times_end[8]),int(times_end[9])):
  ang_10.append(data_float[i])


del ang_2[0]
del ang_3[0]
del ang_4[0]
del ang_5[0]
del ang_6[0]
del ang_7[0]
del ang_8[0]
del ang_9[0]
del ang_10[0]


time1=[]
chemcon=[]
DAG=[]
GLU_SEN=[]
V_POST=[]
x_1=[]
y_1=[]
probabilidades=[]
glu_basal=[]

for i in ang_1:
  time1.append(i[0])
  chemcon.append(i[1])
  DAG.append(i[2])
  GLU_SEN.append(i[3])
  V_POST.append(i[4])
  x_1.append(i[5])
  y_1.append(i[6])
  probabilidades.append(i[7])
  #glu_basal.append(i[8])

time2=[]
chemcon2=[]
x_2=[]
y_2=[]
for i in ang_2:
  time2.append(i[0])
  #DAG.append(i[2])
  chemcon2.append(i[1])
  V_POST.append(i[4])
  x_2.append(i[5])
  y_2.append(i[6])
  #glu_basal.append(i[8])

  
time3=[]
chemcon3=[]
x_3=[]
y_3=[]
for i in ang_3:
  time3.append(i[0])
  #DAG.append(i[2])
  chemcon3.append(i[1])
  V_POST.append(i[4])
  x_3.append(i[5])
  y_3.append(i[6])
  #glu_basal.append(i[8])


time4=[]
chemcon4=[]
x_4=[]
y_4=[]
for i in ang_4:
  time4.append(i[0])
  #DAG.append(i[2])
  chemcon4.append(i[1])
  V_POST.append(i[4])
  x_4.append(i[5])
  y_4.append(i[6])
  #glu_basal.append(i[8])


time5=[]
chemcon5=[]
x_5=[]
y_5=[]
for i in ang_5:
  time5.append(i[0])
  #DAG.append(i[2])
  chemcon5.append(i[1])
  V_POST.append(i[4])
  x_5.append(i[5])
  y_5.append(i[6])
 # glu_basal.append(i[8])


time6=[]
chemcon6=[]
x_6=[]
y_6=[]
for i in ang_6:
  time6.append(i[0])
  chemcon6.append(i[1])
  V_POST.append(i[4])
  x_6.append(i[5])
  y_6.append(i[6])
  #glu_basal.append(i[8])


time7=[]
chemcon7=[]
x_7=[]
y_7=[]
for i in ang_7:
  time7.append(i[0])
  chemcon7.append(i[1])
  V_POST.append(i[4])
  x_7.append(i[5])
  y_7.append(i[6])
  #glu_basal.append(i[8])



time8=[]
chemcon8=[]
x_8=[]
y_8=[]
for i in ang_8:
  time8.append(i[0])
  chemcon8.append(i[1])
  V_POST.append(i[4])
  x_8.append(i[5])
  y_8.append(i[6])
  #glu_basal.append(i[8])

time9=[]
chemcon9=[]
x_9=[]
y_9=[]
for i in ang_9:
  time9.append(i[0])
  chemcon9.append(i[1])
  V_POST.append(i[4])
  x_9.append(i[5])
  y_9.append(i[6])
  #glu_basal.append(i[8])

time10=[]
chemcon10=[]
x_10=[]
y_10=[]
for i in ang_10:
  time10.append(i[0])
  chemcon10.append(i[1])
  V_POST.append(i[4])
  x_10.append(i[5])
  y_10.append(i[6])
  #glu_basal.append(i[8])

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plt.scatter(x=x_1,y=y_1, c= time1)
plt.scatter(x=x_2,y=y_2, c= time2)
plt.scatter(x=x_3,y=y_3, c= time3)
plt.scatter(x=x_4,y=y_4, c= time4)
plt.scatter(x=x_5,y=y_5, c= time5)
plt.scatter(x=x_6,y=y_6, c= time6)
plt.scatter(x=x_7,y=y_7, c= time7)
plt.scatter(x=x_8,y=y_8, c= time8)
plt.scatter(x=x_9,y=y_9, c= time9)
plt.scatter(x=x_10,y=y_10, c= time10)
cbar = plt.colorbar()
cbar.set_label('time (s)', rotation=270, labelpad=20, fontsize=14)
#plt.axvline(x=3.0, color="b")
plt.plot([-3.0, 3.0],[0.0, 0.0],"k--")
plt.scatter(x=[3.0],y=[0.0], color="r", s=45)
plt.scatter(x=[-3.0],y=[0.0], color="b", s=45)
plt.text(-4.5, -1.40, '30mM', fontsize = 14)
plt.text(2.7, -0.70, '95mM', fontsize = 14)
plt.text(-0.7, 3.0, '50mM', fontsize = 14)
#plt.axvline(x=-3.0, color="b")
#plt.axhline(y=0, color="b")
#plt.axvline(x=0, color="b")
#plt.axhline(y=0, color="b")
circle1 = plt.Circle((0, 0), 4.25, color='r', alpha=0.3)
ax.add_patch(circle1)
ax.tick_params(axis='both', which='major', labelsize=13)
plt.ylabel("y (cm)", fontsize=14)
plt.xlabel("x (cm)", fontsize=14)
plt.xlim((-5,5))
plt.ylim((-5,5))
ax.set_aspect('equal')
ax.set_title('Cultivation at 25mM',fontweight="bold", fontsize=14)
plt.tight_layout()
#plt.savefig("LowSalt.png")
plt.show()

# %%
import matplotlib.pyplot as plt

def create_frame(t):
    fig, ax = plt.subplots()
    plt.plot(x_1[:(t+1)],y_1[:(t+1)], color = 'grey')
    plt.plot(x_1[t], y_1[t], color = 'black', marker = 'o' )
    plt.plot(x_2[:(t+1)],y_2[:(t+1)], color = 'grey')
    plt.plot(x_2[t], y_2[t], color = 'black', marker = 'o' )
    plt.plot(x_3[:(t+1)],y_3[:(t+1)], color = 'grey')
    plt.plot(x_3[t], y_3[t], color = 'black', marker = 'o' )
    plt.plot(x_4[:(t+1)],y_4[:(t+1)], color = 'grey')
    plt.plot(x_4[t], y_4[t], color = 'black', marker = 'o' )
    plt.plot(x_5[:(t+1)],y_5[:(t+1)], color = 'grey')
    plt.plot(x_5[t], y_5[t], color = 'black', marker = 'o' )
    plt.plot(x_6[:(t+1)],y_6[:(t+1)], color = 'grey')
    plt.plot(x_6[t], y_6[t], color = 'black', marker = 'o' )
    plt.plot(x_7[:(t+1)],y_7[:(t+1)], color = 'grey')
    plt.plot(x_7[t], y_7[t], color = 'black', marker = 'o' )
    plt.plot(x_8[:(t+1)],y_8[:(t+1)], color = 'grey')
    plt.plot(x_8[t], y_8[t], color = 'black', marker = 'o' )
    plt.plot(x_9[:(t+1)],y_9[:(t+1)], color = 'grey')
    plt.plot(x_9[t], y_9[t], color = 'black', marker = 'o' )
    plt.plot(x_10[:(t+1)],y_10[:(t+1)], color = 'grey')
    plt.plot(x_10[t], y_10[t], color = 'black', marker = 'o' )

    #plt.axvline(x=3.0, color="b")
    plt.plot([-3.0, 3.0],[0.0, 0.0],"k--")
    plt.scatter(x=[3.0],y=[0.0], color="r", s=45)
    plt.scatter(x=[-3.0],y=[0.0], color="b", s=45)
    plt.text(-4.5, -1.40, '30mM', fontsize = 14)
    plt.text(2.7, -0.70, '95mM', fontsize = 14)
    plt.text(-0.7, 3.0, '50mM', fontsize = 14)
    #plt.axvline(x=-3.0, color="b")
    #plt.axhline(y=0, color="b")
    #plt.axvline(x=0, color="b")
    #plt.axhline(y=0, color="b")
    circle1 = plt.Circle((0, 0), 4.25, color='r', alpha=0.3)
    ax.add_patch(circle1)
    ax.tick_params(axis='both', which='major', labelsize=13)
    plt.ylabel("y (cm)", fontsize=14)
    plt.xlabel("x (cm)", fontsize=14)
    plt.xlim((-5,5))
    plt.ylim((-5,5))
    ax.set_aspect('equal')
    ax.set_title('Cultivation at 25mM',fontweight="bold", fontsize=14)
    plt.tight_layout()
    plt.savefig(f'./gif_low/img_{t}.png', 
                transparent = False,  
                facecolor = 'white'
               )
    plt.close()

# %%
for t in range(len(x_2)):
    if t%1400 == 0:
        create_frame(t)

# %% [markdown]
# # Medium salt

# %%
import numpy as np
def ldata(archive):
    f=open(archive)
    data=[]
    for line in f:
        e=line.strip()
        col=line.split()
        data.append(col)	
    return data


#data=ldata("/content/gdrive/MyDrive/Colab Notebooks/paper/ATRACCION_trayectorias.txt")
data=ldata("random_trayectorias.txt")
#data=ldata("/content/gdrive/MyDrive/Colab Notebooks/paper/random_trayectorias.txt")
data_float=[]
data_time=[]
for i in data:
  data_float.append([float(i[0]), float(i[1]), float(i[2]), float(i[3]), float(i[4]), float(i[5]), float(i[6]), float(i[7])])
  data_time.append(float(i[0]))

# %%
times_end = np.argwhere(np.array(data_time) == max(data_time))

# %%
ang_1 = []
ang_2 = []
ang_3 = []
ang_4 = []
ang_5 = []
ang_6 = []
ang_7 = []
ang_8 = []
ang_9 = []
ang_10 = []
for i in range(int(times_end[0])):
  ang_1.append(data_float[i])
for i in range(int(times_end[0]),int(times_end[1])):
  ang_2.append(data_float[i])
for i in range(int(times_end[1]),int(times_end[2])):
  ang_3.append(data_float[i])
for i in range(int(times_end[2]),int(times_end[3])):
  ang_4.append(data_float[i])
for i in range(int(times_end[3]),int(times_end[4])):
  ang_5.append(data_float[i])
for i in range(int(times_end[4]),int(times_end[5])):
  ang_6.append(data_float[i])
for i in range(int(times_end[5]),int(times_end[6])):
  ang_7.append(data_float[i])
for i in range(int(times_end[6]),int(times_end[7])):
  ang_8.append(data_float[i])
for i in range(int(times_end[7]),int(times_end[8])):
  ang_9.append(data_float[i])
for i in range(int(times_end[8]),int(times_end[9])):
  ang_10.append(data_float[i])


del ang_2[0]
del ang_3[0]
del ang_4[0]
del ang_5[0]
del ang_6[0]
del ang_7[0]
del ang_8[0]
del ang_9[0]
del ang_10[0]


time1=[]
chemcon=[]
DAG=[]
GLU_SEN=[]
V_POST=[]
x_1=[]
y_1=[]
probabilidades=[]
glu_basal=[]

for i in ang_1:
  time1.append(i[0])
  chemcon.append(i[1])
  DAG.append(i[2])
  GLU_SEN.append(i[3])
  V_POST.append(i[4])
  x_1.append(i[5])
  y_1.append(i[6])
  probabilidades.append(i[7])
  #glu_basal.append(i[8])

time2=[]
chemcon2=[]
x_2=[]
y_2=[]
for i in ang_2:
  time2.append(i[0])
  #DAG.append(i[2])
  chemcon2.append(i[1])
  V_POST.append(i[4])
  x_2.append(i[5])
  y_2.append(i[6])
  #glu_basal.append(i[8])

  
time3=[]
chemcon3=[]
x_3=[]
y_3=[]
for i in ang_3:
  time3.append(i[0])
  #DAG.append(i[2])
  chemcon3.append(i[1])
  V_POST.append(i[4])
  x_3.append(i[5])
  y_3.append(i[6])
  #glu_basal.append(i[8])


time4=[]
chemcon4=[]
x_4=[]
y_4=[]
for i in ang_4:
  time4.append(i[0])
  #DAG.append(i[2])
  chemcon4.append(i[1])
  V_POST.append(i[4])
  x_4.append(i[5])
  y_4.append(i[6])
  #glu_basal.append(i[8])


time5=[]
chemcon5=[]
x_5=[]
y_5=[]
for i in ang_5:
  time5.append(i[0])
  #DAG.append(i[2])
  chemcon5.append(i[1])
  V_POST.append(i[4])
  x_5.append(i[5])
  y_5.append(i[6])
 # glu_basal.append(i[8])


time6=[]
chemcon6=[]
x_6=[]
y_6=[]
for i in ang_6:
  time6.append(i[0])
  chemcon6.append(i[1])
  V_POST.append(i[4])
  x_6.append(i[5])
  y_6.append(i[6])
  #glu_basal.append(i[8])


time7=[]
chemcon7=[]
x_7=[]
y_7=[]
for i in ang_7:
  time7.append(i[0])
  chemcon7.append(i[1])
  V_POST.append(i[4])
  x_7.append(i[5])
  y_7.append(i[6])
  #glu_basal.append(i[8])



time8=[]
chemcon8=[]
x_8=[]
y_8=[]
for i in ang_8:
  time8.append(i[0])
  chemcon8.append(i[1])
  V_POST.append(i[4])
  x_8.append(i[5])
  y_8.append(i[6])
  #glu_basal.append(i[8])

time9=[]
chemcon9=[]
x_9=[]
y_9=[]
for i in ang_9:
  time9.append(i[0])
  chemcon9.append(i[1])
  V_POST.append(i[4])
  x_9.append(i[5])
  y_9.append(i[6])
  #glu_basal.append(i[8])

time10=[]
chemcon10=[]
x_10=[]
y_10=[]
for i in ang_10:
  time10.append(i[0])
  chemcon10.append(i[1])
  V_POST.append(i[4])
  x_10.append(i[5])
  y_10.append(i[6])
  #glu_basal.append(i[8])

# %%
import matplotlib.pyplot as plt

def create_frame(t):
    fig, ax = plt.subplots()
    plt.plot(x_1[:(t+1)],y_1[:(t+1)], color = 'grey')
    plt.plot(x_1[t], y_1[t], color = 'black', marker = 'o' )
    plt.plot(x_2[:(t+1)],y_2[:(t+1)], color = 'grey')
    plt.plot(x_2[t], y_2[t], color = 'black', marker = 'o' )
    plt.plot(x_3[:(t+1)],y_3[:(t+1)], color = 'grey')
    plt.plot(x_3[t], y_3[t], color = 'black', marker = 'o' )
    plt.plot(x_4[:(t+1)],y_4[:(t+1)], color = 'grey')
    plt.plot(x_4[t], y_4[t], color = 'black', marker = 'o' )
    plt.plot(x_5[:(t+1)],y_5[:(t+1)], color = 'grey')
    plt.plot(x_5[t], y_5[t], color = 'black', marker = 'o' )
    plt.plot(x_6[:(t+1)],y_6[:(t+1)], color = 'grey')
    plt.plot(x_6[t], y_6[t], color = 'black', marker = 'o' )
    plt.plot(x_7[:(t+1)],y_7[:(t+1)], color = 'grey')
    plt.plot(x_7[t], y_7[t], color = 'black', marker = 'o' )
    plt.plot(x_8[:(t+1)],y_8[:(t+1)], color = 'grey')
    plt.plot(x_8[t], y_8[t], color = 'black', marker = 'o' )
    plt.plot(x_9[:(t+1)],y_9[:(t+1)], color = 'grey')
    plt.plot(x_9[t], y_9[t], color = 'black', marker = 'o' )
    plt.plot(x_10[:(t+1)],y_10[:(t+1)], color = 'grey')
    plt.plot(x_10[t], y_10[t], color = 'black', marker = 'o' )

    #plt.axvline(x=3.0, color="b")
    plt.plot([-3.0, 3.0],[0.0, 0.0],"k--")
    plt.scatter(x=[3.0],y=[0.0], color="r", s=45)
    plt.scatter(x=[-3.0],y=[0.0], color="b", s=45)
    plt.text(-4.5, -0.70, '30mM', fontsize = 14)
    plt.text(2.7, -0.70, '95mM', fontsize = 14)
    plt.text(-0.7, 3.0, '50mM', fontsize = 14)
    #plt.axvline(x=-3.0, color="b")
    #plt.axhline(y=0, color="b")
    #plt.axvline(x=0, color="b")
    #plt.axhline(y=0, color="b")
    circle1 = plt.Circle((0, 0), 4.25, color='r', alpha=0.3)
    ax.add_patch(circle1)
    ax.tick_params(axis='both', which='major', labelsize=13)
    plt.ylabel("y (cm)", fontsize=14)
    plt.xlabel("x (cm)", fontsize=14)
    plt.xlim((-5,5))
    plt.ylim((-5,5))
    ax.set_aspect('equal')
    ax.set_title('Cultivation at 50mM',fontweight="bold", fontsize=14)
    plt.tight_layout()
    plt.savefig(f'./gif_medium/img_{t}.png', 
                transparent = False,  
                facecolor = 'white'
               )
    plt.close()

# %%
for t in range(len(x_2)):
    if t%1400 == 0:
        create_frame(t)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plt.scatter(x=x_1,y=y_1, c= time1)
plt.scatter(x=x_2,y=y_2, c= time2)
plt.scatter(x=x_3,y=y_3, c= time3)
plt.scatter(x=x_4,y=y_4, c= time4)
plt.scatter(x=x_5,y=y_5, c= time5)
plt.scatter(x=x_6,y=y_6, c= time6)
plt.scatter(x=x_7,y=y_7, c= time7)
plt.scatter(x=x_8,y=y_8, c= time8)
plt.scatter(x=x_9,y=y_9, c= time9)
plt.scatter(x=x_10,y=y_10, c= time10)
cbar = plt.colorbar()
cbar.set_label('time (s)', rotation=270, labelpad=20, fontsize=14)
#plt.axvline(x=3.0, color="b")
plt.plot([-3.0, 3.0],[0.0, 0.0],"k--")
plt.scatter(x=[3.0],y=[0.0], color="r", s=45)
plt.scatter(x=[-3.0],y=[0.0], color="b", s=45)
plt.text(-4.5, -1.40, '30mM', fontsize = 14)
plt.text(2.7, -0.70, '95mM', fontsize = 14)
plt.text(-0.7, 3.0, '50mM', fontsize = 14)
#plt.axvline(x=-3.0, color="b")
#plt.axhline(y=0, color="b")
#plt.axvline(x=0, color="b")
#plt.axhline(y=0, color="b")
circle1 = plt.Circle((0, 0), 4.25, color='r', alpha=0.3)
ax.add_patch(circle1)
ax.tick_params(axis='both', which='major', labelsize=13)
plt.ylabel("y (cm)", fontsize=14)
plt.xlabel("x (cm)", fontsize=14)
plt.xlim((-5,5))
plt.ylim((-5,5))
ax.set_aspect('equal')
ax.set_title('Cultivation at 50mM',fontweight="bold", fontsize=14)
plt.tight_layout()
#plt.savefig("MediumSalt.png")
plt.show()

# %% [markdown]
# # High salt

# %%
import numpy as np
def ldata(archive):
    f=open(archive)
    data=[]
    for line in f:
        e=line.strip()
        col=line.split()
        data.append(col)	
    return data


#data=ldata("/content/gdrive/MyDrive/Colab Notebooks/paper/ATRACCION_trayectorias.txt")
data=ldata("ATRACCION_trayectorias.txt")
#data=ldata("/content/gdrive/MyDrive/Colab Notebooks/paper/random_trayectorias.txt")
data_float=[]
data_time=[]
for i in data:
  data_float.append([float(i[0]), float(i[1]), float(i[2]), float(i[3]), float(i[4]), float(i[5]), float(i[6]), float(i[7])])
  data_time.append(float(i[0]))

# %%
times_end = np.argwhere(np.array(data_time) == max(data_time))

# %%
ang_1 = []
ang_2 = []
ang_3 = []
ang_4 = []
ang_5 = []
ang_6 = []
ang_7 = []
ang_8 = []
ang_9 = []
ang_10 = []
for i in range(int(times_end[0])):
  ang_1.append(data_float[i])
for i in range(int(times_end[0]),int(times_end[1])):
  ang_2.append(data_float[i])
for i in range(int(times_end[1]),int(times_end[2])):
  ang_3.append(data_float[i])
for i in range(int(times_end[2]),int(times_end[3])):
  ang_4.append(data_float[i])
for i in range(int(times_end[3]),int(times_end[4])):
  ang_5.append(data_float[i])
for i in range(int(times_end[4]),int(times_end[5])):
  ang_6.append(data_float[i])
for i in range(int(times_end[5]),int(times_end[6])):
  ang_7.append(data_float[i])
for i in range(int(times_end[6]),int(times_end[7])):
  ang_8.append(data_float[i])
for i in range(int(times_end[7]),int(times_end[8])):
  ang_9.append(data_float[i])
for i in range(int(times_end[8]),int(times_end[9])):
  ang_10.append(data_float[i])


del ang_2[0]
del ang_3[0]
del ang_4[0]
del ang_5[0]
del ang_6[0]
del ang_7[0]
del ang_8[0]
del ang_9[0]
del ang_10[0]


time1=[]
chemcon=[]
DAG=[]
GLU_SEN=[]
V_POST=[]
x_1=[]
y_1=[]
probabilidades=[]
glu_basal=[]

for i in ang_1:
  time1.append(i[0])
  chemcon.append(i[1])
  DAG.append(i[2])
  GLU_SEN.append(i[3])
  V_POST.append(i[4])
  x_1.append(i[5])
  y_1.append(i[6])
  probabilidades.append(i[7])
  #glu_basal.append(i[8])

time2=[]
chemcon2=[]
x_2=[]
y_2=[]
for i in ang_2:
  time2.append(i[0])
  #DAG.append(i[2])
  chemcon2.append(i[1])
  V_POST.append(i[4])
  x_2.append(i[5])
  y_2.append(i[6])
  #glu_basal.append(i[8])

  
time3=[]
chemcon3=[]
x_3=[]
y_3=[]
for i in ang_3:
  time3.append(i[0])
  #DAG.append(i[2])
  chemcon3.append(i[1])
  V_POST.append(i[4])
  x_3.append(i[5])
  y_3.append(i[6])
  #glu_basal.append(i[8])


time4=[]
chemcon4=[]
x_4=[]
y_4=[]
for i in ang_4:
  time4.append(i[0])
  #DAG.append(i[2])
  chemcon4.append(i[1])
  V_POST.append(i[4])
  x_4.append(i[5])
  y_4.append(i[6])
  #glu_basal.append(i[8])


time5=[]
chemcon5=[]
x_5=[]
y_5=[]
for i in ang_5:
  time5.append(i[0])
  #DAG.append(i[2])
  chemcon5.append(i[1])
  V_POST.append(i[4])
  x_5.append(i[5])
  y_5.append(i[6])
 # glu_basal.append(i[8])


time6=[]
chemcon6=[]
x_6=[]
y_6=[]
for i in ang_6:
  time6.append(i[0])
  chemcon6.append(i[1])
  V_POST.append(i[4])
  x_6.append(i[5])
  y_6.append(i[6])
  #glu_basal.append(i[8])


time7=[]
chemcon7=[]
x_7=[]
y_7=[]
for i in ang_7:
  time7.append(i[0])
  chemcon7.append(i[1])
  V_POST.append(i[4])
  x_7.append(i[5])
  y_7.append(i[6])
  #glu_basal.append(i[8])



time8=[]
chemcon8=[]
x_8=[]
y_8=[]
for i in ang_8:
  time8.append(i[0])
  chemcon8.append(i[1])
  V_POST.append(i[4])
  x_8.append(i[5])
  y_8.append(i[6])
  #glu_basal.append(i[8])

time9=[]
chemcon9=[]
x_9=[]
y_9=[]
for i in ang_9:
  time9.append(i[0])
  chemcon9.append(i[1])
  V_POST.append(i[4])
  x_9.append(i[5])
  y_9.append(i[6])
  #glu_basal.append(i[8])

time10=[]
chemcon10=[]
x_10=[]
y_10=[]
for i in ang_10:
  time10.append(i[0])
  chemcon10.append(i[1])
  V_POST.append(i[4])
  x_10.append(i[5])
  y_10.append(i[6])
  #glu_basal.append(i[8])

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plt.scatter(x=x_1,y=y_1, c= time1)
plt.scatter(x=x_2,y=y_2, c= time2)
plt.scatter(x=x_3,y=y_3, c= time3)
plt.scatter(x=x_4,y=y_4, c= time4)
plt.scatter(x=x_5,y=y_5, c= time5)
plt.scatter(x=x_6,y=y_6, c= time6)
plt.scatter(x=x_7,y=y_7, c= time7)
plt.scatter(x=x_8,y=y_8, c= time8)
plt.scatter(x=x_9,y=y_9, c= time9)
plt.scatter(x=x_10,y=y_10, c= time10)
cbar = plt.colorbar()
cbar.set_label('time (s)', rotation=270, labelpad=20, fontsize=14)
#plt.axvline(x=3.0, color="b")
plt.plot([-3.0, 3.0],[0.0, 0.0],"k--")
plt.scatter(x=[3.0],y=[0.0], color="r", s=45)
plt.scatter(x=[-3.0],y=[0.0], color="b", s=45)
plt.text(-4.5, -1.40, '30mM', fontsize = 14)
plt.text(2.7, -0.70, '95mM', fontsize = 14)
plt.text(-0.7, 3.0, '50mM', fontsize = 14)
#plt.axvline(x=-3.0, color="b")
#plt.axhline(y=0, color="b")
#plt.axvline(x=0, color="b")
#plt.axhline(y=0, color="b")
circle1 = plt.Circle((0, 0), 4.25, color='r', alpha=0.3)
ax.add_patch(circle1)
ax.tick_params(axis='both', which='major', labelsize=13)
plt.ylabel("y (cm)", fontsize=14)
plt.xlabel("x (cm)", fontsize=14)
plt.xlim((-5,5))
plt.ylim((-5,5))
ax.set_aspect('equal')
ax.set_title('Cultivation at 100mM',fontweight="bold", fontsize=14)
plt.tight_layout()
#plt.savefig("HighSalt.png")
plt.show()

# %%
def create_frame(t):
    fig = plt.figure(figsize=(6, 6))
    plt.plot(x[:(t+1)], y[:(t+1)], color = 'grey' )
    plt.plot(x[t], y[t], color = 'black', marker = 'o' )
    plt.xlim([0,5])
    plt.xlabel('x', fontsize = 14)
    plt.ylim([0,5])
    plt.ylabel('y', fontsize = 14)
    plt.title(f'Relationship between x and y at step {t}',
              fontsize=14)
    plt.savefig(f'./img/img_{t}.png', 
                transparent = False,  
                facecolor = 'white'
               )
    plt.close()

# %%
import matplotlib.pyplot as plt

def create_frame(t):
    fig, ax = plt.subplots()
    plt.plot(x_1[:(t+1)],y_1[:(t+1)], color = 'grey')
    plt.plot(x_1[t], y_1[t], color = 'black', marker = 'o' )
    plt.plot(x_2[:(t+1)],y_2[:(t+1)], color = 'grey')
    plt.plot(x_2[t], y_2[t], color = 'black', marker = 'o' )
    plt.plot(x_3[:(t+1)],y_3[:(t+1)], color = 'grey')
    plt.plot(x_3[t], y_3[t], color = 'black', marker = 'o' )
    plt.plot(x_4[:(t+1)],y_4[:(t+1)], color = 'grey')
    plt.plot(x_4[t], y_4[t], color = 'black', marker = 'o' )
    plt.plot(x_5[:(t+1)],y_5[:(t+1)], color = 'grey')
    plt.plot(x_5[t], y_5[t], color = 'black', marker = 'o' )
    plt.plot(x_6[:(t+1)],y_6[:(t+1)], color = 'grey')
    plt.plot(x_6[t], y_6[t], color = 'black', marker = 'o' )
    plt.plot(x_7[:(t+1)],y_7[:(t+1)], color = 'grey')
    plt.plot(x_7[t], y_7[t], color = 'black', marker = 'o' )
    plt.plot(x_8[:(t+1)],y_8[:(t+1)], color = 'grey')
    plt.plot(x_8[t], y_8[t], color = 'black', marker = 'o' )
    plt.plot(x_9[:(t+1)],y_9[:(t+1)], color = 'grey')
    plt.plot(x_9[t], y_9[t], color = 'black', marker = 'o' )
    plt.plot(x_10[:(t+1)],y_10[:(t+1)], color = 'grey')
    plt.plot(x_10[t], y_10[t], color = 'black', marker = 'o' )

    #plt.axvline(x=3.0, color="b")
    plt.plot([-3.0, 3.0],[0.0, 0.0],"k--")
    plt.scatter(x=[3.0],y=[0.0], color="r", s=45)
    plt.scatter(x=[-3.0],y=[0.0], color="b", s=45)
    plt.text(-4.5, -0.70, '30mM', fontsize = 14)
    plt.text(2.7, -0.70, '95mM', fontsize = 14)
    plt.text(-0.7, 3.0, '50mM', fontsize = 14)
    #plt.axvline(x=-3.0, color="b")
    #plt.axhline(y=0, color="b")
    #plt.axvline(x=0, color="b")
    #plt.axhline(y=0, color="b")
    circle1 = plt.Circle((0, 0), 4.25, color='r', alpha=0.3)
    ax.add_patch(circle1)
    ax.tick_params(axis='both', which='major', labelsize=13)
    plt.ylabel("y (cm)", fontsize=14)
    plt.xlabel("x (cm)", fontsize=14)
    plt.xlim((-5,5))
    plt.ylim((-5,5))
    ax.set_aspect('equal')
    ax.set_title('Cultivation at 100mM',fontweight="bold", fontsize=14)
    plt.tight_layout()
    plt.savefig(f'./gif_high/img_{t}.png', 
                transparent = False,  
                facecolor = 'white'
               )
    plt.close()

# %%
len(x_2)/1400
# Out:
# 42.864285714285714

# %%
len(x_2)
# Out:
# 60010

# %%
60010/62
# Out:
# 967.9032258064516

# %%
for t in range(len(x_2)):
    if t%1400 == 0:
        create_frame(t)

# %% [markdown]
# # Chemotaxis index for wild type and mutants
# The C.I.s are calculated in the chemotaxis_index.ipynb notebook

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np





fig, axes = plt.subplots( figsize=(12, 5))
# create data
x = np.arange(9)
# WT, sensing chemical, DAG GF, PKC
y1 = [-0.8328282828282828, 0.0014450275947566812, 0.2628684807256236, -0.8481481481481481
, -0.8521344414054282, 0.0, 0.0, -0.01710940760176753, -0.8316666666666666]   #low salt 
y2 = [0.0, -0.0019841156358829668, 0.9616666666666666, -0.8846801346801346
, -0.8849999999999999, 0.0, 0.0, 0.18214209026444286, -0.16407120262492578] # intermediate salt
y3 = [0.8116666666666665, 0.03841763707097737, 0.8766666666666666, -0.7571043771043771
, -0.24015707158137975, 0.0, 0.0, 0.7946969696969698, -0.013946741383641803] # high salt 
width = 0.2

c1 = [0.03235856654573886, 0.02322444681586236, 0.048581039401801314, 0.04287602954408232
, 0.03137377552897049, 0.01, 0.01, 0.03926677949172543, 0.03920034013457875] #low salt
c2 = [0.01, 0.02565517836046355, 0.021369760566432795, 0.04123066856689427
, 0.02664582518894848, 0.01, 0.01, 0.03185720168573996, 0.043954193462997906] # intermediate salt
c3 = [0.032506409624359696, 0.026396130945381107, 0.023380903889000264, 0.048367352019941544 
, 0.052836175342585855, 0.01, 0.01, 0.03481909168840435, 0.0184080619461722] # high salt



pval=["*","**","*"]
plt.plot([-0.4,0,8.4], [0,0,0], "k", lw=1.0)
plt.axvline(x=0.5, lw=2, color="k", alpha=1.0, ls="--")
plt.axvline(x=3.5, lw=2, color="k", alpha=1.0, ls="--")
# plot data in grouped manner of bar type
plt.bar(x-0.2, y1, width, yerr=c1, color="#1f77b4", label = "25mM") # low salt


plt.bar(x, y2, width, yerr=c2, color='orange', label = "50mM") # middle salt

plt.bar(x+0.2, y3, width, yerr=c3, color='r', label = "100mM") # high salt



plt.xticks(x, ['WT', "NaCl sensing (lf)", 'DAG (gf)', 'pkc-1 (lf)',  'DAG (lf)', 'PKG (lf)', 'PKG (gf)', r'$\omega_{\mathrm{inh}}$ (lf)', r'$\omega_{\mathrm{exc}}$ (lf)'], fontsize=12, rotation=50)


#plt.xlabel("Teams")
plt.ylabel("Chemotaxis index", fontsize=12)

lg = plt.legend(title="Cultivation at:", fontsize=12)
#plt.legend(["Round 1", "Round 2", "Round 3"])
title = lg.get_title()
title.set_fontsize('large') # xx-large
plt.tight_layout()
#plt.savefig("CI_wt_mutants.png", dpi=500)
plt.show()

# %%
fig, axes = plt.subplots( figsize=(12, 5))
# create data
x = np.arange(9)
# WT, sensing chemical, DAG GF, PKC
y1 = [-0.8328282828282828, 0.0014450275947566812, 0.2628684807256236, -0.8481481481481481
, -0.8521344414054282, 0.0, 0.0, -0.01710940760176753, -0.8316666666666666]   #low salt 
y2 = [0.0, -0.0019841156358829668, 0.9616666666666666, -0.8846801346801346
, -0.8849999999999999, 0.0, 0.0, 0.18214209026444286, -0.16407120262492578] # intermediate salt
y3 = [0.8116666666666665, 0.03841763707097737, 0.8766666666666666, -0.7571043771043771
, -0.24015707158137975, 0.0, 0.0, 0.7946969696969698, -0.013946741383641803] # high salt 
width = 0.2

c1 = [0.03235856654573886, 0.02322444681586236, 0.048581039401801314, 0.04287602954408232
, 0.03137377552897049, 0.01, 0.01, 0.03926677949172543, 0.03920034013457875] #low salt
c2 = [0.01, 0.02565517836046355, 0.021369760566432795, 0.04123066856689427
, 0.02664582518894848, 0.01, 0.01, 0.03185720168573996, 0.043954193462997906] # intermediate salt
c3 = [0.032506409624359696, 0.026396130945381107, 0.023380903889000264, 0.048367352019941544 
, 0.052836175342585855, 0.01, 0.01, 0.03481909168840435, 0.0184080619461722] # high salt



pval=["*","**","*"]
plt.plot([-0.4,0,8.4], [0,0,0], "k", lw=1.0)
plt.axvline(x=0.5, lw=2, color="k", alpha=1.0, ls="--")
plt.axvline(x=3.5, lw=2, color="k", alpha=1.0, ls="--")
# plot data in grouped manner of bar type
plt.bar(x-0.2, y1, width, yerr=c1, color="#1f77b4", label = "25mM") # low salt


plt.bar(x, y2, width, yerr=c2, color='orange', label = "50mM") # middle salt

plt.bar(x+0.2, y3, width, yerr=c3, color='r', label = "100mM") # high salt



plt.xticks(x, ['WT', "NaCl sensing (lf)", 'DAG (gf)', 'pkc-1 (lf)',  'DAG (lf)', 'PKG (lf)', 'PKG (gf)', r'$\omega_{\mathrm{inh}}$ (lf)', r'$\omega_{\mathrm{exc}}$ (lf)'], fontsize=13, rotation=50)


#plt.xlabel("Teams")
#plt.ylabel("Chemotaxis index", fontsize=12)
plt.ylabel("Chemotaxis index", fontsize=16)
plt.yticks( fontsize=12)
lg = plt.legend(title="Cultivation at:", fontsize=12)
#plt.legend(["Round 1", "Round 2", "Round 3"])
title = lg.get_title()
title.set_fontsize('large') # xx-large
plt.tight_layout()
#plt.savefig("CI_wt_mutants.png", dpi=500)
plt.savefig("CI_wt_mutants.pdf")
plt.show()

# %%
# some example data
threshold = 0.0

x= [r"$\alpha$", r"$K$",r"$\delta_{\mathrm{GMP}}$",r"$\delta_{\mathrm{PKG}}$",r"$\gamma$",r"$\beta$",r"$\delta_{\mathrm{Ca}}$",r"$b$",r"$\beta_{\mathrm{DAG}}$",r"$\delta_{\mathrm{DAG}}$",r"$\alpha_{\mathrm{Glu}}$",r"$\alpha_{\Delta}$",r"$\theta$",r"$\tau$"
    ,r"$\omega_{\mathrm{inh}}$" ,r"$b_{\mathrm{inh}}$", r"$\theta_{\mathrm{inh}}$", r"$\omega_{\mathrm{exc}}$", r"$b_{\mathrm{exc}}$", r"$\theta_{\mathrm{exc}}$", r"$\omega_{\mathrm{low}}$", r"$\omega_{\mathrm{high}}$", r"$V_{\mathrm{low}}$", r"$\beta_{\mathrm{Glu}}$"]

# and plot it

fig, ax = plt.subplots( figsize=(12, 5))
spacing = (range(len(x)))
new_spacing = [1.5*i for i in spacing]

ax.plot([-0.99,0,new_spacing[-1] + 1.25], [0,0,0], "k", lw=1.0)
ax.bar(np.array(new_spacing) -  0.25, mean_data_mas_20_25_float, width=0.5, yerr=std_data_mas_20_25_float, color="#1f77b4", label = "25mM")
#ax.bar(np.array(new_spacing) , mean_data_mas_20_50_float, width=0.5, yerr=std_data_mas_20_50_float, color='orange', label = "50mM")
ax.bar(np.array(new_spacing) + 0.25, mean_data_mas_20_100_float, width=0.5, yerr=std_data_mas_20_100_float, color='r', label = "100mM")
plt.xticks(new_spacing, x, fontsize=13, rotation=50)
plt.yticks( fontsize=12)



plt.ylabel("Chemotaxis index", fontsize=16)
lg = plt.legend(title="Cultivation at:", fontsize=12, loc = "lower right")
#plt.legend(["Round 1", "Round 2", "Round 3"])
title = lg.get_title()
#title.set_fontsize('large') # xx-large
plt.title("Perturbation: +50%", fontsize=16)
plt.tight_layout()
#plt.savefig("perturbation_mas_50.png", dpi=500)
plt.savefig("perturbation_mas_50.pdf")
plt.show()
